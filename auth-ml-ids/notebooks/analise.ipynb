# %%
import matplotlib.pyplot as plt

# Etapas do projeto com base nas pastas e ferramentas mencionadas
etapas = [
    'Backend (API de Autenticação)',
    'Machine Learning (Modelo de Detecção)',
    'Segurança (Suricata, TShark, YARA)',
    'Logs de Eventos de Segurança',
    'Fake Train App (Testes de Detecção)',
    'Regras e Monitoramento'
]

# Progresso (em porcentagem)
progresso = [10, 25, 40, 50, 70, 100]

# Criando o gráfico
plt.figure(figsize=(10, 6))
plt.plot(etapas, progresso, marker='o', linestyle='-', color='g')

# Adicionando título e rótulos
plt.title('Progresso do Projeto: Detecção de Acesso Suspeito')
plt.xlabel('Etapas do Projeto')
plt.ylabel('Progresso (%)')

# Rotacionando os rótulos no eixo X para melhor visualização
plt.xticks(rotation=45, ha="right")

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
# Carregar os dados dos logs de alerta do Suricata
with open('../backend/seguranca/logs/suricata_alertas.json') as f:
    suricata_alertas = json.load(f)

# Exibir os primeiros logs
suricata_alertas[:2]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Carregar os dados dos logs de alerta do Suricata
#       2 with open('../backend/seguranca/logs/suricata_alertas.json') as f:
# ----> 3     suricata_alertas = json.load(f)
#       5 # Exibir os primeiros logs
#       6 suricata_alertas[:2]
#
# File /usr/lib/python3.13/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# ...
